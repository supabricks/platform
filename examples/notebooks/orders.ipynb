# %% [markdown]
# # Orders on a local snapshot
# Import an orders CSV into public.orders, select its branch, then start the kernel. This notebook does not start or run automatically.

# %%
spark.sql('SELECT * FROM public.orders LIMIT 20').show()

# %%
spark.sql('SELECT SUM(CAST(amount AS DECIMAL(18, 2))) AS total FROM public.orders').show()
